# %%
pwd
# Out:
# 'C:\\Users\\Petra'

# %%
cd C://Users//Petra//Desktop
# Out:
# C:\Users\Petra\Desktop

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
podaci = pd.read_csv("training_dataset_enc.csv")

# %%
del podaci['Unnamed: 0'], podaci['Unnamed: 0.1']
podaci.head()
# Out:
#   DATUM_IZVJESTAVANJA  KLIJENT_ID  OZNAKA_PARTIJE DATUM_OTVARANJA  \
# 0          31.12.2013      412140         7146814      27.08.2012
# 1          31.12.2013      772139         5521579      11.06.2010
# 2          31.12.2013      481985         7443823      23.01.2013
# 3          31.12.2013      139014         6511639      16.09.2011
# 4          31.12.2013      952566         6143123      23.05.2011
#
#   PLANIRANI_DATUM_ZATVARANJA DATUM_ZATVARANJA  UGOVORENI_IZNOS  \
# 0                 30.04.2018              NaN        629155.97
# 1                 30.06.2017              NaN         46000.00
# 2                 28.02.2018              NaN         44679.50
# 3                 30.09.2016              NaN         29959.15
# 4                 31.05.2014              NaN        100000.00
#
#    STANJE_NA_KRAJU_PRETH_KVARTALA  STANJE_NA_KRAJU_KVARTALA  VALUTA  \
# 0                       639373.81                 641562.01       2
# ...

# %%
podaci.describe()
# Out:
#          KLIJENT_ID  OZNAKA_PARTIJE  UGOVORENI_IZNOS  \
# count  5.193124e+06    5.193124e+06     5.193124e+06
# mean   7.207398e+05    7.152089e+06     2.554007e+05
# std    1.160615e+07    8.765659e+06     3.784332e+06
# min    1.002000e+03    1.630070e+05     0.000000e+00
# 25%    3.708580e+05    4.275223e+06     2.956673e+04
# 50%    6.930290e+05    6.603912e+06     6.422751e+04
# 75%    1.033071e+06    9.142953e+06     1.150000e+05
# max    9.991411e+09    1.136257e+08     6.055048e+08
#
#        STANJE_NA_KRAJU_PRETH_KVARTALA  STANJE_NA_KRAJU_KVARTALA        VALUTA  \
# count                    4.772056e+06              5.193124e+06  5.193124e+06
# mean                     1.309054e+05              1.181028e+05  1.682643e+00
# std                      1.950900e+06              1.829336e+06  8.221024e-01
# min                     -5.981000e+01             -5.981000e+01  1.000000e+00
# 25%                      6.897520e+03              4.032975e+02  1.000000e+00
# ...

# %%
podaci[podaci['STAROST'] >= 900].count() # 467
# Out:
# DATUM_IZVJESTAVANJA               467
# KLIJENT_ID                        467
# OZNAKA_PARTIJE                    467
# DATUM_OTVARANJA                   467
# PLANIRANI_DATUM_ZATVARANJA        405
# DATUM_ZATVARANJA                  144
# UGOVORENI_IZNOS                   467
# STANJE_NA_KRAJU_PRETH_KVARTALA    417
# STANJE_NA_KRAJU_KVARTALA          467
# VALUTA                            467
# VRSTA_KLIJENTA                    467
# PROIZVOD                          467
# VRSTA_PROIZVODA                   467
# VISINA_KAMATE                     462
# TIP_KAMATE                        467
# STAROST                           467
# PRIJEVREMENI_RASKID               467
# dtype: int64

# %%
podaci[podaci['STAROST'] < 0].count() # 3367
# Out:
# DATUM_IZVJESTAVANJA               3367
# KLIJENT_ID                        3367
# OZNAKA_PARTIJE                    3367
# DATUM_OTVARANJA                   3367
# PLANIRANI_DATUM_ZATVARANJA        3307
# DATUM_ZATVARANJA                   373
# UGOVORENI_IZNOS                   3367
# STANJE_NA_KRAJU_PRETH_KVARTALA    3307
# STANJE_NA_KRAJU_KVARTALA          3367
# VALUTA                            3367
# VRSTA_KLIJENTA                    3367
# PROIZVOD                          3367
# VRSTA_PROIZVODA                   3367
# VISINA_KAMATE                     3363
# TIP_KAMATE                        3367
# STAROST                           3367
# PRIJEVREMENI_RASKID               3367
# dtype: int64

# %%
podaci[['KLIJENT_ID','OZNAKA_PARTIJE','DATUM_OTVARANJA']].drop_duplicates().count() # 579636, s datumom otvaranja 950239
# Out:
# KLIJENT_ID         950239
# OZNAKA_PARTIJE     950239
# DATUM_OTVARANJA    950239
# dtype: int64

# %%
podaci[['KLIJENT_ID']].drop_duplicates().count() # 256958 klijenata
# Out:
# KLIJENT_ID    256858
# dtype: int64

# %%
podaci[['DATUM_OTVARANJA']].drop_duplicates().count() # 6207 jedinstvenih datuma
# Out:
# DATUM_OTVARANJA    6207
# dtype: int64

# %% [markdown]
# Ideja je organizirati podatke po datumu otvaranja, uvesti to kao indeks za dohvaćanje podataka. (vedgar pr3)
# Prvo ih treba pretvoriti u drugi format jer ih se ovako ne može sortirati uzlazno.
# Primijeniti isti format i na ostale datume u podacima.

# %%
import datetime
print(podaci['DATUM_OTVARANJA'].head())
# Out:
# 0    27.08.2012
# 1    11.06.2010
# 2    23.01.2013
# 3    16.09.2011
# 4    23.05.2011
# Name: DATUM_OTVARANJA, dtype: object

# %%
podaci['PLANIRANI_DATUM_ZATVARANJA'] = pd.to_datetime(podaci['PLANIRANI_DATUM_ZATVARANJA'], format = "%d.%m.%Y")
podaci['DATUM_IZVJESTAVANJA'] = pd.to_datetime(podaci['DATUM_IZVJESTAVANJA'], format = "%d.%m.%Y")
podaci['DATUM_OTVARANJA'] = pd.to_datetime(podaci['DATUM_OTVARANJA'], format = "%d.%m.%Y")

# %%
podaci.sort_index(inplace=True)

# %%
podaci.head()
# Out:
#   DATUM_IZVJESTAVANJA  KLIJENT_ID  OZNAKA_PARTIJE DATUM_OTVARANJA  \
# 0          2013-12-31      412140         7146814      2012-08-27
# 1          2013-12-31      772139         5521579      2010-06-11
# 2          2013-12-31      481985         7443823      2013-01-23
# 3          2013-12-31      139014         6511639      2011-09-16
# 4          2013-12-31      952566         6143123      2011-05-23
#
#   PLANIRANI_DATUM_ZATVARANJA DATUM_ZATVARANJA  UGOVORENI_IZNOS  \
# 0                 2018-04-30              NaN        629155.97
# 1                 2017-06-30              NaN         46000.00
# 2                 2018-02-28              NaN         44679.50
# 3                 2016-09-30              NaN         29959.15
# 4                 2014-05-31              NaN        100000.00
#
#    STANJE_NA_KRAJU_PRETH_KVARTALA  STANJE_NA_KRAJU_KVARTALA  VALUTA  \
# 0                       639373.81                 641562.01       2
# ...

# %%
podaci[['KLIJENT_ID','OZNAKA_PARTIJE','DATUM_IZVJESTAVANJA']].drop_duplicates().count()  # JEDINSTVENI KLJUC
# Out:
# KLIJENT_ID             5193124
# OZNAKA_PARTIJE         5193124
# DATUM_IZVJESTAVANJA    5193124
# dtype: int64

# %%
dat_zat = podaci['DATUM_ZATVARANJA'] # ako zatriba

# %%
del podaci['DATUM_ZATVARANJA']

# %%
podaci.head()
# Out:
#   DATUM_IZVJESTAVANJA  KLIJENT_ID  OZNAKA_PARTIJE DATUM_OTVARANJA  \
# 0          2013-12-31      412140         7146814      2012-08-27
# 1          2013-12-31      772139         5521579      2010-06-11
# 2          2013-12-31      481985         7443823      2013-01-23
# 3          2013-12-31      139014         6511639      2011-09-16
# 4          2013-12-31      952566         6143123      2011-05-23
#
#   PLANIRANI_DATUM_ZATVARANJA  UGOVORENI_IZNOS  STANJE_NA_KRAJU_PRETH_KVARTALA  \
# 0                 2018-04-30        629155.97                       639373.81
# 1                 2017-06-30         46000.00                        28481.94
# 2                 2018-02-28         44679.50                        44908.40
# 3                 2016-09-30         29959.15                        19691.64
# 4                 2014-05-31        100000.00                        24797.93
#
#    STANJE_NA_KRAJU_KVARTALA  VALUTA  VRSTA_KLIJENTA PROIZVOD VRSTA_PROIZVODA  \
# ...

# %%
podaci.isnull().sum()
# Out:
# DATUM_IZVJESTAVANJA                    0
# KLIJENT_ID                             0
# OZNAKA_PARTIJE                         0
# DATUM_OTVARANJA                        0
# PLANIRANI_DATUM_ZATVARANJA        421129
# UGOVORENI_IZNOS                        0
# STANJE_NA_KRAJU_PRETH_KVARTALA    421068
# STANJE_NA_KRAJU_KVARTALA               0
# VALUTA                                 0
# VRSTA_KLIJENTA                         0
# PROIZVOD                               0
# VRSTA_PROIZVODA                        0
# VISINA_KAMATE                      51702
# TIP_KAMATE                             0
# STAROST                                0
# PRIJEVREMENI_RASKID                    0
# dtype: int64

# %%
podaci['STAROST'].values[podaci['STAROST'].values >= 900] = -1
podaci['STAROST'].values[podaci['STAROST'].values < 0] = -1

# %%
podaci[podaci['UGOVORENI_IZNOS']==0.0].count() # 1158
# Out:
# DATUM_IZVJESTAVANJA               1158
# KLIJENT_ID                        1158
# OZNAKA_PARTIJE                    1158
# DATUM_OTVARANJA                   1158
# PLANIRANI_DATUM_ZATVARANJA         948
# UGOVORENI_IZNOS                   1158
# STANJE_NA_KRAJU_PRETH_KVARTALA     963
# STANJE_NA_KRAJU_KVARTALA          1158
# VALUTA                            1158
# VRSTA_KLIJENTA                    1158
# PROIZVOD                          1158
# VRSTA_PROIZVODA                   1158
# VISINA_KAMATE                      943
# TIP_KAMATE                        1158
# STAROST                           1158
# PRIJEVREMENI_RASKID               1158
# dtype: int64

# %%
podaci['GODINE']=podaci['DATUM_IZVJESTAVANJA'].dt.year

# %%
podaci.set_index('GODINE', inplace=True)
podaci.sort_index(inplace=True)
podaci.head()
# Out:
#        DATUM_IZVJESTAVANJA  KLIJENT_ID  OZNAKA_PARTIJE DATUM_OTVARANJA  \
# GODINE
# 2011            2011-06-30      206116         5695263      2010-10-25
# 2011            2011-09-30      782396         6144200      2011-05-27
# 2011            2011-09-30     1047539          531897      2007-06-29
# 2011            2011-09-30     1133342         3685048      2008-06-10
# 2011            2011-09-30      470005         1382695      2008-02-21
#
#        PLANIRANI_DATUM_ZATVARANJA  UGOVORENI_IZNOS  \
# GODINE
# 2011                   2011-04-26         40375.26
# 2011                   2016-05-31         40143.84
# 2011                   2011-07-06          5900.61
# 2011                   2011-06-21          7387.43
# 2011                   2015-02-28         54601.83
#
#         STANJE_NA_KRAJU_PRETH_KVARTALA  STANJE_NA_KRAJU_KVARTALA  VALUTA  \
# GODINE
# 2011                          40605.44                  40556.70       2
# ...

# %%
podaci2 = podaci[['UGOVORENI_IZNOS','STANJE_NA_KRAJU_PRETH_KVARTALA','STANJE_NA_KRAJU_KVARTALA','VRSTA_PROIZVODA']]
podaci3 = podaci[['UGOVORENI_IZNOS','STANJE_NA_KRAJU_PRETH_KVARTALA','STANJE_NA_KRAJU_KVARTALA','VRSTA_PROIZVODA', 'PRIJEVREMENI_RASKID']]

# %%
podaci2[podaci2['VRSTA_PROIZVODA'] == 'A']#.plot()
# A = kredit, L = stednja

podaci3 = podaci3[podaci3['VRSTA_PROIZVODA'] == 'L']

podaci3[podaci3['PRIJEVREMENI_RASKID'] == 'Y'].count() # 147836

proba = podaci3[podaci3['PRIJEVREMENI_RASKID'] == 'Y']
proba[proba['STANJE_NA_KRAJU_KVARTALA'] == 0.0].count()  # 147836

# svi štediše koji su prijevremeno raskinuli, imaju stanje na kraju računa 0
# Out:
# UGOVORENI_IZNOS                   147836
# STANJE_NA_KRAJU_PRETH_KVARTALA    147836
# STANJE_NA_KRAJU_KVARTALA          147836
# VRSTA_PROIZVODA                   147836
# PRIJEVREMENI_RASKID               147836
# dtype: int64

# %%
podaci4 = podaci3[podaci3['VRSTA_PROIZVODA'] == 'A']

podaci4[podaci4['PRIJEVREMENI_RASKID'] == 'Y'].count() # 168469

proba = podaci4[podaci4['PRIJEVREMENI_RASKID'] == 'Y']
proba[proba['STANJE_NA_KRAJU_KVARTALA'] == 0.0].count()  # 168130

# ljudi koji su uzeli kredit i prijevremeno raskinuli ugovor, nisu svi u potpunosti otplatili??
# Out:
# UGOVORENI_IZNOS                   168130
# STANJE_NA_KRAJU_PRETH_KVARTALA    168130
# STANJE_NA_KRAJU_KVARTALA          168130
# VRSTA_PROIZVODA                   168130
# PRIJEVREMENI_RASKID               168130
# dtype: int64

# %%
prekidi = podaci.loc[podaci['PRIJEVREMENI_RASKID']=='Y']
prekidi_group = prekidi.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])
len1 = len(prekidi_group);
print('Broj prijevremenih raskida: ', len1)

sve_grupe = podaci.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])
len2 = len(sve_grupe);
print('Ukupan broj ugovora: ', len2)
print('Postotak prijevremenih raskida u datasetu: ', len1/len2 )
# Out:
# Broj prijevremenih raskida:  160155
# Ukupan broj ugovora:  950239
# Postotak prijevremenih raskida u datasetu:  0.16854180895543122

# %%
#prekidi_group.head()

# %%
econ = pd.read_excel('ekonom.xlsx')
# ovo izbacuje retke s puno nan-ova (one prazne u file-u )
econ.dropna(thresh=int(econ.shape[1] * .9), axis = 0, inplace = True)
column_names = econ.columns
# Drop unwanted columns
econ.drop(column_names[0], inplace=True, axis=1)
column_names = econ.columns
print(column_names)
econ.rename(columns={'Unnamed: 2': '2000', 'Unnamed: 3': '2001', 
                   'Unnamed: 4': '2002', 'Unnamed: 5': '2003', 
                   'Unnamed: 6': '2004', 'Unnamed: 7': '2005',
                  'Unnamed: 8': '2006', 'Unnamed: 9': '2007', 
                  'Unnamed: 10': '2008', 'Unnamed: 11': '2009',
                  'Unnamed: 12': '2010', 'Unnamed: 13': '2011',
                  'Unnamed: 14': '2012', 'Unnamed: 15': '2013',
                  'Unnamed: 16': '2014', 'Unnamed: 17': '2015',
                  'Unnamed: 18': '2016', 'Unnamed: 19': '2017',
                  'Unnamed: 20': '2018'}, inplace=True)

econ.drop([3], axis = 0, inplace = True)
# Out:
# Index(['General information on Croatia', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
econ.head()
# Out:
#         General information on Croatia     2000     2001           2002  \
# 4                     Area (square km)    56594    56594   56594.000000
# 5               Population (million) a    4.426  4.30549       4.305384
# 6  GDP (million HRK, current prices) b   180241   194271  211500.384280
# 7   GDP (million EUR, current prices)   23610.7  26003.3   28554.214875
# 8            GDP per capita (in EUR)    5334.56  6039.56    6632.210942
#
#             2003           2004           2005           2006           2007  \
# 4   56594.000000   56594.000000   56594.000000   56594.000000   56594.000000
# 5       4.305725       4.310861       4.312487       4.313530       4.311967
# 6  232444.050150  250564.762188  269779.451979  294150.258439  322463.846521
# 7   30729.300540   33427.889423   36456.451152   40168.827520   43956.244732
# 8    7136.846998    7754.341748    8453.695316    9312.286577   10194.012322
#
# ...

# %%
econ=econ.T

# %%
new_header = econ.iloc[0] #grab the first row for the header
econ = econ[1:] #take the data less the header row
econ.columns = new_header #set the header row as the df header

# %%
econ['GODINE'] = range(2000,2019)
econ.head()
# Out:
# General information on Croatia Area (square km) Population (million) a  \
# 2000                                      56594                  4.426
# 2001                                      56594                4.30549
# 2002                                      56594                4.30538
# 2003                                      56594                4.30572
# 2004                                      56594                4.31086
#
# General information on Croatia GDP (million HRK, current prices) b  \
# 2000                                                        180241
# 2001                                                        194271
# 2002                                                        211500
# 2003                                                        232444
# 2004                                                        250565
#
# General information on Croatia GDP (million EUR, current prices)   \
# ...

# %%
econ.columns
# Out:
# Index(['Area (square km)', 'Population (million) a',
#        'GDP (million HRK, current prices) b',
#        'GDP (million EUR, current prices) ', 'GDP per capita (in EUR)  ',
#        'GDP - year-on-year rate of growth (in %, constant prices) ',
#        'Average CPI year-on-year inflation rate ',
#        'Current account balance (million EUR) c',
#        'Current account balance (as of % GDP) ',
#        'Exports of goods and services (as of % GDP) ',
#        'Imports of goods and services (as of % GDP) ',
#        'External debt (million EUR, end of year) c',
#        'External debt (as of % GDP) ',
#        'External debt (as of % exports of goods and services) ',
#        'External debt service (as % of exports of goods and services) d',
#        'Gross international reserves (million EUR, end of year)',
#        'Gross international reserves (in terms of months of imports of goods and services, end of year)',
#        'Exchange rate on 31 December (HRK : 1 EUR)',
# ...

# %% [markdown]
# Potrebno je izbaciti neke stupce iz econ tablice, npr. povrsina ili vrijednosti u drugim valutama, također odlučiti hoćemo li koristiti nezaposlenost ili zaposlenost, ne treba oboje (možda bolje zaposlenost).

# %%
del econ['Area (square km)'], econ['Population (million) a'], econ['GDP (million EUR, current prices) ']
del econ['GDP per capita (in EUR)  '], econ['Current account balance (million EUR) c']
del econ['Exports of goods and services (as of % GDP) '], econ['Imports of goods and services (as of % GDP) ']
del econ['External debt (million EUR, end of year) c'], econ['External debt (as of % GDP) ']
del econ['External debt (as of % exports of goods and services) '], econ['External debt service (as % of exports of goods and services) d']
del econ['Gross international reserves (million EUR, end of year)']
del econ['Gross international reserves (in terms of months of imports of goods and services, end of year)']
del econ['Exchange rate on 31 December (HRK : 1 EUR)'], econ['Exchange rate on 31 December  (HRK : 1 USD)']
del econ['Average exchange rate (HRK : 1 EUR) '], econ['Average exchange rate (HRK : 1 USD) ']
del econ['Consolidated general government net lending (+)/borrowing (-) (million HRK) e']
del econ['Consolidated general government net lending (+)/borrowing (-) (as % of GDP) e']
del econ['Unemployment rate (ILO, persons above 15 years of age) f']
#export, import izbacit, reserves, rate(7.4), consolidated, external debt, stopa nezaposlenosti
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Area (square km)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-32e782c1de1d> in <module>()
# ...

# %%
econ.columns
# Out:
# Index(['GDP (million HRK, current prices) b',
#        'GDP - year-on-year rate of growth (in %, constant prices) ',
#        'Average CPI year-on-year inflation rate ',
#        'Current account balance (as of % GDP) ',
#        'General government debt (as % of GDP) e',
#        'Employment rate (ILO, persons above 15 years of age) f', 'GODINE'],
#       dtype='object', name='General information on Croatia')

# %%
econ.set_index('GODINE', inplace=True)
econ.sort_index(inplace=True)
econ.head()
# Out:
# General information on Croatia GDP (million HRK, current prices) b  \
# GODINE
# 2000                                                        180241
# 2001                                                        194271
# 2002                                                        211500
# 2003                                                        232444
# 2004                                                        250565
#
# General information on Croatia GDP - year-on-year rate of growth (in %, constant prices)   \
# GODINE
# 2000                                                                       3.7675
# 2001                                                                      3.45241
# 2002                                                                      5.25336
# 2003                                                                      5.58119
# 2004                                                                      3.91456
#
# ...

# %%
econ.drop([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010], axis=0,inplace=True)

# %%
popis= [5440.6, 5477.9, 5514.8, 5533.5, 5594.3, 5685.1, 5984.4, 6241.1]
econ['Prosjek_placaN'] = popis
econ.head()
# Out:
# General information on Croatia GDP (million HRK, current prices) b  \
# GODINE
# 2011                                                        333457
# 2012                                                        330825
# 2013                                                        331785
# 2014                                                        331570
# 2015                                                        339616
#
# General information on Croatia GDP - year-on-year rate of growth (in %, constant prices)   \
# GODINE
# 2011                                                                     -0.34019
# 2012                                                                     -2.30064
# 2013                                                                    -0.491749
# 2014                                                                   -0.0875134
# 2015                                                                      2.40059
#
# ...

# %%
podaci.head().describe()
# Out:
#          KLIJENT_ID  OZNAKA_PARTIJE  UGOVORENI_IZNOS  \
# count  5.000000e+00    5.000000e+00           5.0000
# mean   7.278796e+05    3.487821e+06       29681.7940
# std    3.899649e+05    2.506845e+06       21836.8736
# min    2.061160e+05    5.318970e+05        5900.6100
# 25%    4.700050e+05    1.382695e+06        7387.4300
# 50%    7.823960e+05    3.685048e+06       40143.8400
# 75%    1.047539e+06    5.695263e+06       40375.2600
# max    1.133342e+06    6.144200e+06       54601.8300
#
#        STANJE_NA_KRAJU_PRETH_KVARTALA  STANJE_NA_KRAJU_KVARTALA    VALUTA  \
# count                        5.000000                  5.000000  5.000000
# mean                     22717.990000              15762.210000  1.600000
# std                      20899.834178              21598.639358  0.547723
# min                          0.000000                  0.000000  1.000000
# 25%                          0.000000                  0.000000  1.000000
# ...
