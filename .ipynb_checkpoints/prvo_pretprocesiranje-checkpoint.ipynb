# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# nakon što stavimo datoteke na Git uvijek čitati u ovomo obliku! (štedi vrijeme)
import time
start = time.time()
df = pd.read_hdf('./data/raw/training_dataset.h5', 'df')
end = time.time()
print(end - start)

# nakon što napravimo promjene kako treba, exportat ću ih u novu datoteku pomoću naredbe
# df.to_hdf('training_dataset2.h5', key='df')

# %%
### NAPOMENA S FAQ-a
df['PRIJEVREMENI_RASKID'] = np.where(df['DATUM_ZATVARANJA']>=(df['PLANIRANI_DATUM_ZATVARANJA']- np.timedelta64(10, 'D')), 'N', df['PRIJEVREMENI_RASKID'])

# %%
### BRISANJE PARTIJA S VIŠE KLIJENATA
old_shape = df.shape
gb = df.groupby('OZNAKA_PARTIJE')['KLIJENT_ID'].nunique() # baci broj jedinstvenih klijenata za pojedinu partiju
# party_labels = df2['OZNAKA_PARTIJE'].unique().tolist() 
mask = gb[df['OZNAKA_PARTIJE']] == 1 # gb[df2['OZNAKA_PARTIJE']] vrati za svaku oznaku partije (svaki redak tablice) njenu vrijednost i usporedi je s 1
df = df[ mask.values ] # mask je neki objekt koji moram ovako koristiti, rezultat je skup gdje za svaku partiju ima jedan klijent
print('Postotak originalnog dataset-a:')
print(df.shape[0]/old_shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1cc5b0f140d7> in <module>
#       1 ### BRISANJE PARTIJA S VIŠE KLIJENATA
# ----> 2 old_shape = df.shape
#       3 gb = df.groupby('OZNAKA_PARTIJE')['KLIJENT_ID'].nunique() # baci broj jedinstvenih klijenata za pojedinu partiju
#       4 # party_labels = df2['OZNAKA_PARTIJE'].unique().tolist()
#       5 mask = gb[df['OZNAKA_PARTIJE']] == 1 # gb[df2['OZNAKA_PARTIJE']] vrati za svaku oznaku partije (svaki redak tablice) njenu vrijednost i usporedi je s 1
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (5187239, 17)

# %%
df.head()
# Out:
#   DATUM_IZVJESTAVANJA  KLIJENT_ID  OZNAKA_PARTIJE DATUM_OTVARANJA  \
# 0          2013-12-31      412140         7146814      2012-08-27
# 1          2013-12-31      772139         5521579      2010-06-11
# 2          2013-12-31      481985         7443823      2013-01-23
# 3          2013-12-31      139014         6511639      2011-09-16
# 4          2013-12-31      952566         6143123      2011-05-23
#
#   PLANIRANI_DATUM_ZATVARANJA DATUM_ZATVARANJA  UGOVORENI_IZNOS  \
# 0                 2018-04-30              NaT        629155.97
# 1                 2017-06-30              NaT         46000.00
# 2                 2018-02-28              NaT         44679.50
# 3                 2016-09-30              NaT         29959.15
# 4                 2014-05-31              NaT        100000.00
#
#    STANJE_NA_KRAJU_PRETH_KVARTALA  STANJE_NA_KRAJU_KVARTALA  VALUTA  \
# 0                       639373.81                 641562.01       2
# 1                        28481.94                  26887.19       1
# 2                        44908.40                  45062.09       2
# 3                        19691.64                  18285.89       2
# 4                        24797.93                  15685.33       1
#
#    VRSTA_KLIJENTA PROIZVOD VRSTA_PROIZVODA  VISINA_KAMATE TIP_KAMATE  STAROST  \
# 0            1420   TM0109               L           1.50          A       22
# 1            1410   FL0801               A           9.70          B       38
# 2            1550   FD0100               L           3.10          A       37
# 3            1410   FL0801               A           7.95          B       49
# 4            1410   FL0801               A           9.70          B       35
#
#   PRIJEVREMENI_RASKID
# 0                   N
# 1                   N
# 2                   N
# 3                   N
# 4                   N

# %%
df.isnull().sum()
# Out:
# DATUM_IZVJESTAVANJA                     0
# KLIJENT_ID                              0
# OZNAKA_PARTIJE                          0
# DATUM_OTVARANJA                         0
# PLANIRANI_DATUM_ZATVARANJA         420978
# DATUM_ZATVARANJA                  3973234
# UGOVORENI_IZNOS                         0
# STANJE_NA_KRAJU_PRETH_KVARTALA     420917
# STANJE_NA_KRAJU_KVARTALA                0
# VALUTA                                  0
# VRSTA_KLIJENTA                          0
# PROIZVOD                                0
# VRSTA_PROIZVODA                         0
# VISINA_KAMATE                       51684
# TIP_KAMATE                              0
# STAROST                                 0
# PRIJEVREMENI_RASKID                     0
# dtype: int64

# %%
df.describe()
# Out:
#          KLIJENT_ID  OZNAKA_PARTIJE  UGOVORENI_IZNOS  \
# count  5.187239e+06    5.187239e+06     5.187239e+06
# mean   7.206729e+05    7.153406e+06     2.536863e+05
# std    1.161272e+07    8.757979e+06     3.768251e+06
# min    1.002000e+03    1.630070e+05     0.000000e+00
# 25%    3.708930e+05    4.276645e+06     2.953413e+04
# 50%    6.930060e+05    6.605459e+06     6.414009e+04
# 75%    1.032869e+06    9.143072e+06     1.150000e+05
# max    9.991411e+09    1.136257e+08     6.055048e+08
#
#        STANJE_NA_KRAJU_PRETH_KVARTALA  STANJE_NA_KRAJU_KVARTALA        VALUTA  \
# count                    4.766322e+06              5.187239e+06  5.187239e+06
# mean                     1.295566e+05              1.168920e+05  1.682218e+00
# std                      1.920337e+06              1.801749e+06  8.217323e-01
# min                     -5.981000e+01             -5.981000e+01  1.000000e+00
# 25%                      6.878780e+03              3.977950e+02  1.000000e+00
# 50%                      3.335964e+04              2.670734e+04  2.000000e+00
# 75%                      8.274797e+04              7.624641e+04  2.000000e+00
# max                      6.105662e+08              6.105662e+08  5.000000e+00
#
#        VRSTA_KLIJENTA  VISINA_KAMATE       STAROST
# count    5.187239e+06   5.135555e+06  5.187239e+06
# mean     1.426424e+03   5.561989e+00  4.140727e+01
# std      6.022722e+01   3.760708e+00  2.046405e+02
# min      1.110000e+03  -4.000000e-03 -7.994000e+03
# 25%      1.410000e+03   2.350000e+00  3.500000e+01
# 50%      1.410000e+03   6.480000e+00  4.600000e+01
# 75%      1.410000e+03   8.740000e+00  5.700000e+01
# max      1.610000e+03   8.080000e+01  9.080000e+02

# %%
# rjesavamo problem nelogicnih vrijednosti starosti; postavit cemo ih na prosjek
# analizom nismo vidjeli neke slicnosti u podacima gdje je starost > 900 ili < 0
logicna_starost = df[(df['STAROST']<900) & (df['STAROST']>=0)]

mean_age = logicna_starost['STAROST'].mean()
df['STAROST'].values[df['STAROST'].values >= 900] = mean_age
df['STAROST'].values[df['STAROST'].values < 0] = mean_age
# df['STAROST'].describe()

# 5072337            1120   FL1310               A            7.0          C
# 1213141            1120   FL0900               A            0.0          B
# 78832              1120   FL0900               A            0.0          B
#
#          STAROST PRIJEVREMENI_RASKID
# 5155888       20                   N
# 4470142       20                   N
# 3522338       20                   N
# 2342921       20                   N
# 1723155       21                   N
# 4673022       21                   N
# 2504157       21                   N
# 2731048       21                   N
# 5097120       22                   N
# 3681824       22                   N
# 1826218       22                   N
# 1792159       22                   N
# 3987089       23                   N
# 3756041       23                   N
# 1619468       23                   N
# 2482720       23                   N
# 5164251       24                   N
# 4282986       24                   N
# 3459210       24                   N
# 3995185       24                   N
# 2803994       25                   N
# 3265996       25                   N
# 1604098       25                   N
# 3144925       25                   N
# 3090595       26                   N
# 5114609       26                   N
# 3219491       26                   N
# 5072337       26                   N
# 1213141       20                   N
# 78832         20                   N

# %%
ugovoreni_iznos_nula = df.copy()
ugovoreni_iznos_nula = ugovoreni_iznos_nula[ugovoreni_iznos_nula['UGOVORENI_IZNOS']==0.0]
ugovoreni_iznos_nula.shape
# ugovoreni iznos = 0 -> ili nema ugovorenog iznosa ili se tek kasnije javlja 
grouped = df.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])

def max_value(series):
    return series.max()

df['UGOVORENI_IZNOS2'] = grouped['UGOVORENI_IZNOS'].transform(max_value)

# %%
ugovoreni_iznos_nula = df[df['UGOVORENI_IZNOS2']==0.0]

# %%
ugovoreni_iznos_nula.shape
# Out:
# (1122, 18)

# %%
## IMPUTACIJA NEDOSTAJUCIH VRIJEDNOSTI

grouped1 = df.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE'])
grouped2 = df.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])

def impute_backwards(series):
    return series.fillna(method = 'bfill')

def impute_mean(series):
    return series.fillna(series.mean())

df['AVG_VISINA_KAMATE'] = grouped1['VISINA_KAMATE'].transform(impute_mean)
df['NOVI_DZ'] = grouped1['DATUM_ZATVARANJA'].transform('last')
df['NOVI_PDZ']  = grouped1['PLANIRANI_DATUM_ZATVARANJA'].transform('last')
df['PRVI_DO']  = grouped2['DATUM_OTVARANJA'].transform('first')

# popunjavanje stanja na kraju prethodnog kvartala 

df['NOVO_STANJE_NKPH'] = np.where(df['STANJE_NA_KRAJU_KVARTALA'].isnull(), df['UGOVORENI_IZNOS'], df['STANJE_NA_KRAJU_KVARTALA'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-92bce6cf376d> in <module>
#       1 ## IMPUTACIJA NEDOSTAJUCIH VRIJEDNOSTI
#       2
# ----> 3 grouped1 = df.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE'])
#       4 grouped2 = df.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])
#       5
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()

# %%
mean_val = df['AVG_VISINA_KAMATE'].mean()
print(mean_val)

# %%
df['AVG_VISINA_KAMATE2'] = np.where(df['AVG_VISINA_KAMATE'].isnull(), mean_val, df['AVG_VISINA_KAMATE'])
df['AVG_VISINA_KAMATE'] = df['AVG_VISINA_KAMATE2']
del df['AVG_VISINA_KAMATE2']

# %%
df.isnull().sum()

# %%
output = df.copy()

output['PLANIRANI_DATUM_ZATVARANJA'] = output['NOVI_PDZ']
output['DATUM_ZATVARANJA'] = output['NOVI_DZ']
output['DATUM_OTVARANJA'] = output['PRVI_DO']
output['STANJE_NA_KRAJU_PRETH_KVARTALA'] = output['NOVO_STANJE_NKPH']
output['VISINA_KAMATE'] = output['AVG_VISINA_KAMATE']

del_col_list = ['NOVI_PDZ', 'NOVI_DZ', 'PRVI_DO', 'NOVO_STANJE_NKPH', 'AVG_VISINA_KAMATE']
output.drop(del_col_list, axis = 1, inplace = True)

# %%
df.shape

# %%
pdz_null = output[output['PLANIRANI_DATUM_ZATVARANJA'].isnull()]

# %%
output.shape

# %%
output2 = output[~(output['DATUM_ZATVARANJA'].isnull())]

# %%
output2.shape

# %%
output2.isnull().sum()

# %%
output2['NOVI_PDZ'] = np.where((output2['PRIJEVREMENI_RASKID']=='N') & (output2['PLANIRANI_DATUM_ZATVARANJA'].isnull()), output2['DATUM_ZATVARANJA'], output2['PLANIRANI_DATUM_ZATVARANJA'])

# %%
output2['PLANIRANI_DATUM_ZATVARANJA'] = output2['NOVI_PDZ']
del output2['NOVI_PDZ']

# %%
output2.shape

# %%
df4 = output2[(output2['DATUM_OTVARANJA']<= output2['PLANIRANI_DATUM_ZATVARANJA']) & (output2['DATUM_OTVARANJA']<= output2['DATUM_ZATVARANJA'])]

# %%
df4.groupby(['PRIJEVREMENI_RASKID']).size()

# %%
### RADITI OVO?
# brisanje outlier-a i ugovorenih iznosa = 0.0
df = df[(df['UGOVORENI_IZNOS'] < 2e5))]

# %%
output2 = output2[output2['UGOVORENI_IZNOS']==0.0]

# %%
output2.shape
# Out:
# (486, 17)

# %%
## POPUNJAVANJE MISSING VALUES UNAZAD (po grupama)

grouped = df.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])
end = time.time()
print( end - start)

# Write a function that imputes median
def impute_backwards(series):
    return series.fillna(method = 'bfill')

start = time.time()
# Impute age and assign to titanic['age']
df['NOVI_DATUM_ZATVARANJA']  = grouped['DATUM_ZATVARANJA'].transform(impute_backwards)
end = time.time()
print(end - start)

start = time.time()
# Impute age and assign to titanic['age']
df['NOVA_VISINA_KAMATE']  = grouped['VISINA_KAMATE'].transform(impute_backwards)
end = time.time()
print(end - start)

# %%
df2 = df.copy()
data = df2.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])
def replace(group):
    group = group.max()
    return group
df2['NOVI_IZNOS'] = data['UGOVORENI_IZNOS'].transform(replace)

# %%
print(ugovoreni_iznos_nula.shape)
ugovoreni_iznos_nula = df2[df2['NOVI_IZNOS']==0.0]
ugovoreni_iznos_nula.shape
# Out:
# (1150, 18)
# (1122, 18)

# %%
razlike = df2[df2['NOVI_IZNOS']> df2['UGOVORENI_IZNOS'] ]

# %%
klijenti = razlike['KLIJENT_ID'].unique()

# %%
klijent = klijenti[0]
proba = df2[df2['KLIJENT_ID']==klijent]

# %%
 # proba = proba[['OZNAKA_PARTIJE', 'DATUM_OTVARANJA', 'DATUM_IZVJESTAVANJA', 'UGOVORENI_IZNOS', 'NOVI_IZNOS']]
proba.sort_values(['OZNAKA_PARTIJE', 'DATUM_OTVARANJA', 'DATUM_IZVJESTAVANJA'], inplace = True)
proba.head(22)
# Out:
#          OZNAKA_PARTIJE DATUM_OTVARANJA DATUM_IZVJESTAVANJA  UGOVORENI_IZNOS  \
# 367632          5649479      2010-09-10          2011-03-31         25100.83
# 1215609         5649479      2010-09-10          2011-06-30         25100.83
# 810338          5649479      2010-09-10          2011-09-30         25100.83
# 717056          5649479      2010-09-10          2011-12-31         25100.83
# 723357          6462948      2011-08-31          2011-09-30          7470.86
# 245682          6462948      2011-08-31          2011-12-31          7470.86
# 558668          6462948      2011-08-31          2012-03-31          7470.86
# 58437           6462948      2011-08-31          2012-06-30          7470.86
# 500700          6462948      2011-08-31          2012-09-30          7680.71
# 21              6462948      2012-09-01          2012-12-31          7680.71
# 846993          6462948      2012-09-01          2013-03-31          7680.71
# 1159940         6462948      2012-09-01          2013-06-30          7680.71
# 384987          6462948      2012-09-01          2013-09-30          7896.17
# 768635          6462948      2013-09-02          2013-12-31          7896.17
# 935337          6462948      2013-09-02          2014-03-31          7896.17
# 538553          6462948      2013-09-02          2014-06-30          7896.17
# 1250574         6462948      2014-09-03          2014-09-30          8094.23
# 964538          6462948      2014-09-03          2014-12-31          8094.23
# 1421904         6462948      2014-09-03          2015-03-31          8094.23
# 1323421         6462948      2014-09-03          2015-06-30          8094.23
# 515385          6462948      2014-09-03          2015-09-30          8094.23
# 720874          6462948      2014-09-03          2015-12-31          8094.23
#
#          NOVI_IZNOS
# 367632     25100.83
# 1215609    25100.83
# 810338     25100.83
# 717056     25100.83
# 723357      7680.71
# 245682      7680.71
# 558668      7680.71
# 58437       7680.71
# 500700      7680.71
# 21          7896.17
# 846993      7896.17
# 1159940     7896.17
# 384987      7896.17
# 768635      7896.17
# 935337      7896.17
# 538553      7896.17
# 1250574     8094.23
# 964538      8094.23
# 1421904     8094.23
# 1323421     8094.23
# 515385      8094.23
# 720874      8094.23

# %%
tablica = razlike[['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA', 'DATUM_IZVJESTAVANJA', 'UGOVORENI_IZNOS', 'NOVI_IZNOS']]

tablica.sort_values(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA', 'DATUM_IZVJESTAVANJA', 'UGOVORENI_IZNOS', 'NOVI_IZNOS'])
# Out:
#          KLIJENT_ID  OZNAKA_PARTIJE DATUM_OTVARANJA DATUM_IZVJESTAVANJA  \
# 5155888        1002          168061      2007-04-04          2011-03-31
# 4470142        1002          168061      2007-04-04          2011-06-30
# 4606182  9991410999        11512692      2016-04-04          2017-09-30
# 4774970  9991410999        11512692      2016-04-04          2017-12-31
#
#          UGOVORENI_IZNOS   NOVI_IZNOS
# 5155888       1035165.83   1035165.83
# 4470142       1035165.83   1035165.83
# 3522338       1035165.83   1035165.83
# 2342921       1035165.83   1035165.83
# 1723155       1035165.83   1035165.83
# 4673022       1035165.83   1035165.83
# 2504157       1035165.83   1035165.83
# 2731048       1035165.83   1035165.83
# 5097120       1035165.83   1035165.83
# 3681824       1035165.83   1035165.83
# 1826218       1035165.83   1035165.83
# 1792159       1035165.83   1035165.83
# 3987089       1035165.83   1035165.83
# 3756041       1035165.83   1035165.83
# 1619468       1035165.83   1035165.83
# 2482720       1035165.83   1035165.83
# 5164251       1035165.83   1035165.83
# 4282986       1035165.83   1035165.83
# 3459210       1035165.83   1035165.83
# 3995185       1035165.83   1035165.83
# 2803994       1035165.83   1035165.83
# 3265996       1035165.83   1035165.83
# 1604098       1035165.83   1035165.83
# 3144925       1035165.83   1035165.83
# 3090595       1035165.83   1035165.83
# 5114609       1035165.83   1035165.83
# 3219491       1035165.83   1035165.83
# 5072337       1035165.83   1035165.83
# 1213141      20154791.73  20154791.73
# 78832        20154791.73  20154791.73
# ...                  ...          ...
# 4961076         74900.00     74900.00
# 3168248          8869.07      8869.07
# 1536861         80000.00     80000.00
# 2735200        123955.00    123955.00
# 4241199        105600.00    105600.00
# 3089335         20000.00     20000.00
# 2889662         11000.00     11000.00
# 2005200         44830.00     44830.00
# 1549659          9000.00      9000.00
# 4572659         29000.00     29000.00
# 4316084         80000.00     80000.00
# 3401887          4800.00      4800.00
# 2705212        100000.00    100000.00
# 1570010        118000.00    118000.00
# 3586570         11000.00     11000.00
# 3195984         37079.92     37079.92
# 4578296          7000.00      7000.00
# 4566190          6200.00      6200.00
# 4553585        118688.56    118688.56
# 3394105          2400.00      2400.00
# 2017114          2400.00      2400.00
# 2954750          8700.00      8700.00
# 1544456          3000.00      3000.00
# 5113980         96127.49     96127.49
# 3017086         96127.49     96127.49
# 4984521         96127.49     96127.49
# 2624313         96127.49     96127.49
# 3887448         96127.49     96127.49
# 4606182         96127.49     96127.49
# 4774970         96127.49     96127.49
#
# [5187239 rows x 6 columns]

# %%
ugovoreni_iznos_nula = ugovoreni_iznos_nula[['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA', 'DATUM_IZVJESTAVANJA', 'UGOVORENI_IZNOS', 'NOVI_IZNOS']]
ugovoreni_iznos_nula.sort_values(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA', 'DATUM_IZVJESTAVANJA'])

# %%
df3 = df.copy()
data = df3.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])
def replace(group):
    mask = group<= 0.0 
    group[mask] = group[~mask].min() # mogu se pojaviti i iznosi iz produzetka ugovora koji su veci 
    return group
df3['NOVI_IZNOS'] = data['UGOVORENI_IZNOS'].transform(replace)

# %%
df3 = df.copy()
df3.groupby(['KLIJENT_ID', 'OZNAKA_PARTIJE', 'DATUM_OTVARANJA'])['UGOVORENI_IZNOS'].agg(pd.Series.mode)
# Out:
# KLIJENT_ID  OZNAKA_PARTIJE  DATUM_OTVARANJA
# 1002        168061          2007-04-04         1.03517e+06
#             5903936         2011-02-14         2.01548e+07
#             6403355         2011-07-07         2.19586e+06
#             6426427         2011-08-04         2.21026e+06
#             6501523         2011-09-19         2.23703e+06
#             6548855         2011-10-20         2.23136e+06
#             6592319         2011-11-18         2.23768e+06
#             6643516         2011-12-28         2.25313e+06
#             6726203         2012-02-07         2.49815e+06
#             7146985         2012-09-04         1.01126e+06
#             7220379         2012-10-01               3e+06
#             7288118         2012-11-09         1.50558e+06
#             9956379         2014-08-20         1.57957e+06
#             12254464        2016-10-28         1.59174e+06
# 1013        5903781         2011-02-15             5.7e+06
#             5916726         2011-02-21             9.7e+06
#             5916741         2011-02-22            1.53e+07
#             5916756         2011-02-25             1.5e+07
#             5925862         2011-02-28            1.58e+07
#             5928498         2011-03-01            2.09e+07
#             5928512         2011-03-03            2.02e+07
#             5932846         2011-03-04            2.02e+07
#             6426284         2011-07-28             6.3e+06
#             6501099         2011-09-20             1.3e+07
#             6501118         2011-09-22            1.28e+07
#             6501132         2011-09-26            1.25e+07
#             6501143         2011-09-27            1.42e+07
#             6527461         2011-10-18            1.61e+07
#             6548659         2011-10-19            1.82e+07
#             6548678         2011-10-21             9.2e+06
#                                                   ...
# 1862630     113606649       2018-12-17              195000
# 1862631     113618234       2018-12-27              130000
# 1862666     113624838       2018-12-21               15000
# 1862735     113618763       2018-12-18               60000
# 1862939     113606951       2018-12-24               45000
# 1862984     113623935       2018-12-17                3500
# 1863020     113623740       2018-12-28               74900
# 1863032     113624216       2018-12-17             8869.07
# 1863225     113616654       2018-12-28               80000
# 1863231     113616604       2018-12-18              123955
# 1863234     113606820       2018-12-21              105600
# 1863307     113615793       2018-12-24               20000
# 1863338     113622032       2018-12-19               11000
# 1863343     113618615       2018-12-27               44830
# 1863642     113623420       2018-12-20                9000
# 1863647     113624095       2018-12-31               29000
# 1863648     113615984       2018-12-28               80000
# 1863759     113616837       2018-12-21                4800
# 1863799     113622245       2018-12-21              100000
# 1863950     113608866       2018-12-28              118000
# 1864235     113624015       2018-12-27               11000
# 1864242     113608395       2018-12-27             37079.9
# 1864245     113613341       2018-12-27                7000
# 1864394     113613387       2018-12-28                6200
# 1864400     113622903       2018-12-28              118689
# 1864473     113610344       2018-12-28                2400
# 1864475     113619905       2018-12-28                2400
# 1864492     113624215       2018-12-28                8700
# 1864493     113617476       2018-12-28                3000
# 9991410999  11512692        2016-04-04             96127.5
# Name: UGOVORENI_IZNOS, Length: 949597, dtype: object

# %%
def top_value_count(x, n=5):
    return x.value_counts().head(n)

gb = df.groupby(['name', 'date']).cod
df_top_freq = gb.apply(top_value_count).reset_index()
df_top_freq.rename(columns=dict(level_2='cod', cod='count_cod'))
